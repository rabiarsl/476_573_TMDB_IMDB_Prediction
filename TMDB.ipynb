# %%
import numpy as np
import pandas as pd
import json
import ast
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7c5fcb03c59f> in <module>
# ----> 1 train = pd.read_csv('data/train.csv')
#       2 test = pd.read_csv('data/test.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
train.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
for row in train.itertuples(index=True, name='Pandas'):
    print (getattr(row, "id"), getattr(row, "budget"), getattr(row, "revenue"),getattr(row, "original_title"))
# Out:
# 1 14000000 12314651 Hot Tub Time Machine 2
# 2 40000000 95149435 The Princess Diaries 2: Royal Engagement
# 3 3300000 13092000 Whiplash
# 4 1200000 16000000 Kahaani
# 5 0 3923970 마린보이
# 6 8000000 3261638 Pinocchio and the Emperor of the Night
# 7 14000000 85446075 The Possession
# 8 0 2586511 Control Room
# 9 0 34327391 Muppet Treasure Island
# 10 6000000 18750246 A Mighty Wind
# 11 1000000 117235147 Rocky
# 12 0 22642033 Revenge of the Nerds II: Nerds in Paradise
# 13 15000000 356296601 American Beauty
# 14 53000000 95226116 Be Cool
# 15 102000000 358372926 Minority Report
# 16 500000 198 Šišanje
# 17 26000000 57891803 Red Eye
# 18 0 1234254 The Invisible Woman
# 19 8000000 1749457 Chalet Girl
# 20 32000000 85167639 Transporter 2
# 21 80000000 136159423 Lost in Space
# 22 4000000 36690067 Friday the 13th Part III
# 23 0 100345 V/H/S
# 24 0 17011 InSight
# 25 0 4947717 Black Sheep
# 26 0 8403433 Dr. Giggles
# 27 10000000 13835130 The Spanish Prisoner
# 28 11000000 7847000 What If
# ...

# %%
count = 0
for row in train.itertuples(index=True, name='Pandas'):
    if getattr(row,"budget") == 0:
        count = count + 1
        print (getattr(row, "id"), getattr(row, "budget"), getattr(row, "revenue"),getattr(row, "original_title"))
print(count)
# Out:
# 5 0 3923970 마린보이
# 8 0 2586511 Control Room
# 9 0 34327391 Muppet Treasure Island
# 12 0 22642033 Revenge of the Nerds II: Nerds in Paradise
# 18 0 1234254 The Invisible Woman
# 23 0 100345 V/H/S
# 24 0 17011 InSight
# 25 0 4947717 Black Sheep
# 26 0 8403433 Dr. Giggles
# 32 0 36000000 Caché
# 34 0 7171 ABCs of Death 2
# 37 0 151559 About Adam
# 39 0 92100 Final: The Rapture
# 41 0 163000 Cocaine Cowboys
# 49 0 653951 Wilson
# 53 0 11000000 The Last Flight of Noah's Ark
# 54 0 17514553 For Keeps
# 56 0 36448200 Son in Law
# 57 0 1056938 Joueuse
# 59 0 119563 Were The World Mine
# 63 0 25232289 Fallen
# 68 0 154120 天注定
# 72 0 16756372 Diarios de motocicleta
# 74 0 17393 Český sen
# 79 0 35610100 Sharky's Machine
# 90 0 140081992 Sommersby
# 92 0 215339 Le fate ignoranti
# 94 0 2724474 Hunger
# 96 0 14353 Со мною вот что происходит
# 98 0 73000 Mishen
# 103 0 14961069 바르게 살자
# 104 0 5310554 Won't Back Down
# 105 0 149521495 Recep İvedik 4
# 117 0 311 一九四二
# 118 0 253625427 Wild Hogs
# ...

# %%
count = 0
for row in test.itertuples(index=True, name='Pandas'):
    if getattr(row,"budget") == 0:
        count = count + 1
        print (getattr(row, "id"), getattr(row, "budget"),getattr(row, "original_title"))
print(count)
# Out:
# 3001 0 ディアルガVSパルキアVSダークライ
# 3003 0 Addicted to Love
# 3006 0 SubUrbia
# 3007 0 Drei
# 3012 0 Bande de filles
# 3016 0 Beautiful Boy
# 3019 0 All That Jazz
# 3023 0 Broken Bridges
# 3025 0 The Adderall Diaries
# 3035 0 Obvious Child
# 3040 0 When the Wind Blows
# 3042 0 Best Seller
# 3046 0 The Comfort of Strangers
# 3047 0 To Have and Have Not
# 3049 0 Short Circuit 2
# 3053 0 Beautiful Losers
# 3054 0 बागबान
# 3056 0 Кочегар
# 3059 0 მონანიება
# 3062 0 The Fall
# 3067 0 XX
# 3070 0 The Impostors
# 3073 0 Blind Dating
# 3074 0 Dangerously Close
# 3082 0 Tomboy
# 3087 0 Skateland
# 3088 0 The Queen of Versailles
# 3092 0 American Splendor
# 3100 0 The Final Cut
# 3101 0 Some Kind of Wonderful
# 3103 0 Good Morning, Babilonia
# 3104 0 Double Trouble
# 3109 0 Rookie of the Year
# 3112 0 Syngué sabour, pierre de patience
# 3117 0 Alceste à bicyclette
# 3118 0 Synchronicity
# 3121 0 অপুর সংসার
# 3124 0 Citizenfour
# 3125 0 The Advocate
# 3127 0 Melinda and Melinda
# 3131 0 Emperor
# ...

# %%
count = 0
for row in train.itertuples(index=True, name='Pandas'):
    if getattr(row,"revenue") < 1000:
        count = count + 1
        print (getattr(row, "id"), getattr(row, "budget"), getattr(row, "revenue"),getattr(row, "original_title"))
print(count)
# Out:
# 16 500000 198 Šišanje
# 117 0 311 一九四二
# 151 0 18 Windwalker
# 153 0 241 Paperhouse
# 225 0 500 Gary Gulman: It's About Time
# 270 0 20 Glass: A Portrait of Philip in Twelve Parts
# 281 0 10 Bats
# 313 16000000 12 The Cookout
# 335 1 3 Saamy
# 348 12 1 The Wind in the Willows
# 451 23000000 12 Chasing Liberty
# 499 0 25 Lake of Fire
# 580 0 88 Blood on the Moon
# 640 6 8 Pollock
# 665 0 70 My Summer Story
# 666 0 10 Elektra Luxx
# 696 1 2 Tere Naam
# 887 0 306 Sinapupunan
# 929 0 641 Hammer of the Gods
# 1007 2000000 30 Zyzzyx Road
# 1008 0 60 Billy Gardell: Halftime
# 1056 0 525 Meeting Evil
# 1139 0 30 The Getaway
# 1142 0 11 북촌방향
# 1162 0 121 Sunrise: A Song of Two Humans
# 1191 0 7 He-Man and She-Ra: The Secret of the Sword
# 1199 5 85 Every Which Way But Loose
# 1241 0 126 Khiladi 786
# 1255 0 404 Illégal
# 1282 9000000 46 Death at a Funeral
# 1347 1 5 East of Eden
# 1355 0 422 2:22
# 1377 0 923 Lady Macbeth
# 1480 0 125 A Band Called Death
# 1542 750000 3 Все и сразу
# ...
